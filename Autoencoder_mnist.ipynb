# %%
import keras
import numpy as np
import matplotlib.pyplot as plt

from keras.datasets import mnist
from keras.models import Model
from keras.layers import Input, add
from keras.layers import Layer, Dense, Dropout, Activation, Flatten, Reshape
from keras import regularizers
from keras.regularizers import l2
from keras.layers.convolutional import Conv2D, MaxPooling2D, UpSampling2D, ZeroPadding2D
from keras.utils import np_utils

# %% [markdown]
# #Vanilla Autoencoder

# %% [markdown]
# ##Load Data

# %%
(X_train, _), (X_test, _) = mnist.load_data()

X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)

# %% [markdown]
# ##Normalize the data

# %%
nb_classes = 10

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
X_train = X_train.astype("float32")/255.
X_test = X_test.astype("float32")/255.
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

y_train = np_utils.to_categorical(y_train, nb_classes)
y_test = np_utils.to_categorical(y_test, nb_classes)

print(y_train.shape[0], 'train samples')
print(y_test.shape[0], 'test samples')
# Out:
# X_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ##Flatten the images for the Fully-Connected Networks

# %%
X_train = X_train.reshape((len(X_train), np.prod(X_train.shape[1:])))
X_test = X_test.reshape((len(X_test), np.prod(X_test.shape[1:])))

print(X_train.shape,X_test.shape)
# Out:
# (60000, 784) (10000, 784)

# %% [markdown]
# ##Create the network

# %%
input_size = 784
hidden_size = 64
output_size = 784

# %%
x = Input(shape=(input_size,))
h = Dense(hidden_size, activation='relu')(x)
r = Dense(output_size, activation='sigmoid')(h)

autoencoder = Model(inputs=x, outputs=r)
autoencoder.compile(optimizer='adam', loss='mse')

# %%
autoencoder.summary()
# Out:
# Model: "model_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 784)]             0
#
#  dense_22 (Dense)            (None, 64)                50240
#
#  dense_23 (Dense)            (None, 784)               50960
#
# =================================================================
# Total params: 101,200
# Trainable params: 101,200
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##Training

# %%
epochs = 5
batch_size = 128

history = autoencoder.fit(X_train, X_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(X_test, X_test))
# Out:
# Epoch 1/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0448 - val_loss: 0.0222
# Epoch 2/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0173 - val_loss: 0.0126
# Epoch 3/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0105 - val_loss: 0.0083
# Epoch 4/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0075 - val_loss: 0.0063
# Epoch 5/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0060 - val_loss: 0.0054

# %%
conv_encoder = Model(x, h)
encoded_imgs = conv_encoder.predict(X_test)

# %% [markdown]
# ##Predict on the test set

# %%
decoded_imgs = autoencoder.predict(X_test)

# %% [markdown]
# ##Plot

# %%
n = 10
plt.figure(figsize=(20, 6))
for i in range(n):
    # display original
    ax = plt.subplot(3, n, i+1)
    plt.imshow(X_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    
    # display reconstruction
    ax = plt.subplot(3, n, i+n+1)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()

# %% [markdown]
# ##Plot the losses

# %%
print(history.history.keys())

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'val_loss'])

# %% [markdown]
# #Multilayer autoencoder

# %% [markdown]
# ##Load Data

# %%
(X_train, _), (X_test, _) = mnist.load_data()

X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)

# %% [markdown]
# ##Normalize the data

# %%
nb_classes = 10

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
X_train = X_train.astype("float32")/255.
X_test = X_test.astype("float32")/255.
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

y_train = np_utils.to_categorical(y_train, nb_classes)
y_test = np_utils.to_categorical(y_test, nb_classes)

print(y_train.shape[0], 'train samples')
print(y_test.shape[0], 'test samples')
# Out:
# X_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ##Flatten the images for the Fully-Connected Networks

# %%
X_train = X_train.reshape((len(X_train), np.prod(X_train.shape[1:])))
X_test = X_test.reshape((len(X_test), np.prod(X_test.shape[1:])))

print(X_train.shape,X_test.shape)
# Out:
# (60000, 784) (10000, 784)

# %% [markdown]
# ##Create the network

# %%
input_size = 784
hidden_size = 128
code_size = 64

x = Input(shape=(input_size,))
hidden_1 = Dense(hidden_size, activation='relu')(x)
h = Dense(code_size, activation='relu')(hidden_1)
hidden_2 = Dense(hidden_size, activation='relu')(h)
r = Dense(input_size, activation='sigmoid')(hidden_2)

autoencoder = Model(inputs=x, outputs=r)
autoencoder.compile(optimizer='adam', loss='mse')

# %%
autoencoder.summary()
# Out:
# Model: "model_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 784)]             0
#
#  dense_24 (Dense)            (None, 128)               100480
#
#  dense_25 (Dense)            (None, 64)                8256
#
#  dense_26 (Dense)            (None, 128)               8320
#
#  dense_27 (Dense)            (None, 784)               101136
#
# =================================================================
# Total params: 218,192
# Trainable params: 218,192
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##Training

# %%
epochs = 5
batch_size = 128

history = autoencoder.fit(X_train, X_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(X_test, X_test))
# Out:
# Epoch 1/5
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0403 - val_loss: 0.0186
# Epoch 2/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0154 - val_loss: 0.0126
# Epoch 3/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0115 - val_loss: 0.0101
# Epoch 4/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0097 - val_loss: 0.0087
# Epoch 5/5
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0086 - val_loss: 0.0078

# %% [markdown]
# ##Predict on the test set

# %%
decoded_imgs = autoencoder.predict(X_test)

# %% [markdown]
# ## Plot

# %%
n = 10
plt.figure(figsize=(20, 6))
for i in range(n):
    # display original
    ax = plt.subplot(3, n, i+1)
    plt.imshow(X_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    
    # display reconstruction
    ax = plt.subplot(3, n, i+n+1)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()

# %% [markdown]
# ##Plot the losses

# %%
print(history.history.keys())

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'val_loss'])

# %% [markdown]
# #Convolutional autoencoder

# %% [markdown]
# ##Load Data

# %%
(X_train, _), (X_test, _) = mnist.load_data()

X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)

# %% [markdown]
# ##Normalize the data

# %%
nb_classes = 10

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
X_train = X_train.astype("float32")/255.
X_test = X_test.astype("float32")/255.
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

y_train = np_utils.to_categorical(y_train, nb_classes)
y_test = np_utils.to_categorical(y_test, nb_classes)
# Out:
# X_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ##Create the network

# %%
x = Input(shape=(28, 28,1)) 

# Encoder
conv1_1 = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
pool1 = MaxPooling2D((2, 2), padding='same')(conv1_1)
conv1_2 = Conv2D(8, (3, 3), activation='relu', padding='same')(pool1)
pool2 = MaxPooling2D((2, 2), padding='same')(conv1_2)
conv1_3 = Conv2D(8, (3, 3), activation='relu', padding='same')(pool2)
h = MaxPooling2D((2, 2), padding='same')(conv1_3)


# Decoder
conv2_1 = Conv2D(8, (3, 3), activation='relu', padding='same')(h)
up1 = UpSampling2D((2, 2))(conv2_1)
conv2_2 = Conv2D(8, (3, 3), activation='relu', padding='same')(up1)
up2 = UpSampling2D((2, 2))(conv2_2)
conv2_3 = Conv2D(16, (3, 3), activation='relu')(up2)
up3 = UpSampling2D((2, 2))(conv2_3)
r = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(up3)

autoencoder = Model(inputs=x, outputs=r)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# %%
autoencoder.summary()
# Out:
# Model: "model_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_15 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_21 (Conv2D)          (None, 28, 28, 16)        160
#
#  max_pooling2d_9 (MaxPooling  (None, 14, 14, 16)       0
#  2D)
#
#  conv2d_22 (Conv2D)          (None, 14, 14, 8)         1160
#
#  max_pooling2d_10 (MaxPoolin  (None, 7, 7, 8)          0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 7, 7, 8)           584
#
#  max_pooling2d_11 (MaxPoolin  (None, 4, 4, 8)          0
#  g2D)
#
#  conv2d_24 (Conv2D)          (None, 4, 4, 8)           584
#
#  up_sampling2d_9 (UpSampling  (None, 8, 8, 8)          0
#  2D)
#
#  conv2d_25 (Conv2D)          (None, 8, 8, 8)           584
#
#  up_sampling2d_10 (UpSamplin  (None, 16, 16, 8)        0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 14, 14, 16)        1168
#
#  up_sampling2d_11 (UpSamplin  (None, 28, 28, 16)       0
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 28, 28, 1)         145
#
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##Training

# %%
epochs = 3
batch_size = 128

history = autoencoder.fit(X_train, X_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(X_test, X_test))
# Out:
# Epoch 1/3
# 469/469 [==============================] - 72s 152ms/step - loss: 0.6931 - val_loss: 0.6923
# Epoch 2/3
# 469/469 [==============================] - 71s 152ms/step - loss: 0.6911 - val_loss: 0.6896
# Epoch 3/3
# 469/469 [==============================] - 71s 152ms/step - loss: 0.6875 - val_loss: 0.6849

# %% [markdown]
# ##Predict on test data

# %%
decoded_imgs = autoencoder.predict(X_test)

# %% [markdown]
# ##Plot

# %%
n = 10
plt.figure(figsize=(20, 6))
for i in range(n):
    # display original
    ax = plt.subplot(3, n, i+1)
    plt.imshow(X_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    
    # display reconstruction
    ax = plt.subplot(3, n, i+n+1)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()

# %% [markdown]
# ##Plot the losses

# %%
print(history.history.keys())

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'val_loss'])

# %% [markdown]
# #Regularized autoencoder

# %% [markdown]
# ##1. Sparse autoencoder

# %% [markdown]
# ###Load Data

# %%
(X_train, _), (X_test, _) = mnist.load_data()

X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)

# %% [markdown]
# ###Normalize the data

# %%
nb_classes = 10

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
X_train = X_train.astype("float32")/255.
X_test = X_test.astype("float32")/255.
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

y_train = np_utils.to_categorical(y_train, nb_classes)
y_test = np_utils.to_categorical(y_test, nb_classes)
# Out:
# X_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ###Flatten the images for the Fully-Connected Networks

# %%
X_train = X_train.reshape((len(X_train), np.prod(X_train.shape[1:])))
X_test = X_test.reshape((len(X_test), np.prod(X_test.shape[1:])))

print(X_train.shape,X_test.shape)
# Out:
# (60000, 784) (10000, 784)

# %% [markdown]
# ###Create the network

# %%
input_size = 784
hidden_size = 32
output_size = 784

# %%
x = Input(shape=(input_size,))
h = Dense(hidden_size, activation='relu', activity_regularizer=regularizers.l1(10e-5))(x)
r = Dense(output_size, activation='sigmoid')(h)

autoencoder = Model(inputs=x, outputs=r)
autoencoder.compile(optimizer='adam', loss='mse')

# %% [markdown]
# ###Training

# %%
epochs = 15
batch_size = 128

history = autoencoder.fit(X_train, X_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(X_test, X_test))
# Out:
# Epoch 1/15
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0599 - val_loss: 0.0365
# Epoch 2/15
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0317 - val_loss: 0.0273
# Epoch 3/15
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0251 - val_loss: 0.0226
# Epoch 4/15
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0215 - val_loss: 0.0199
# Epoch 5/15
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0195 - val_loss: 0.0184
# Epoch 6/15
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0183 - val_loss: 0.0175
# Epoch 7/15
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0176 - val_loss: 0.0169
# Epoch 8/15
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0170 - val_loss: 0.0164
# Epoch 9/15
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0165 - val_loss: 0.0160
# Epoch 10/15
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0161 - val_loss: 0.0156
# Epoch 11/15
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0158 - val_loss: 0.0153
# Epoch 12/15
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0156 - val_loss: 0.0151
# Epoch 13/15
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0153 - val_loss: 0.0149
# Epoch 14/15
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0151 - val_loss: 0.0147
# Epoch 15/15
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0149 - val_loss: 0.0145

# %% [markdown]
# ###Predict on the test set

# %%
decoded_imgs = autoencoder.predict(X_test)

# %% [markdown]
# ###Plot

# %%
n = 10
plt.figure(figsize=(20, 6))
for i in range(n):
    # display original
    ax = plt.subplot(3, n, i+1)
    plt.imshow(X_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    
    # display reconstruction
    ax = plt.subplot(3, n, i+n+1)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()

# %% [markdown]
# ###Plot the losses

# %%
print(history.history.keys())

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'val_loss'])

# %% [markdown]
# ##2. Denoising autoencoder

# %% [markdown]
# ###Load Data

# %%
(X_train, _), (X_test, _) = mnist.load_data()

X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)

# %% [markdown]
# ###Create noisy data

# %%
noise_factor = 0.5
X_train_noisy = X_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=X_train.shape) 
X_test_noisy = X_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=X_test.shape) 

X_train_noisy = np.clip(X_train_noisy, 0., 1.)
X_test_noisy = np.clip(X_test_noisy, 0., 1.)

# %% [markdown]
# ###Create the network

# %%
x = Input(shape=(28, 28, 1))

# Encoder
conv1_1 = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
pool1 = MaxPooling2D((2, 2), padding='same')(conv1_1)
conv1_2 = Conv2D(32, (3, 3), activation='relu', padding='same')(pool1)
h = MaxPooling2D((2, 2), padding='same')(conv1_2)


# Decoder
conv2_1 = Conv2D(32, (3, 3), activation='relu', padding='same')(h)
up1 = UpSampling2D((2, 2))(conv2_1)
conv2_2 = Conv2D(32, (3, 3), activation='relu', padding='same')(up1)
up2 = UpSampling2D((2, 2))(conv2_2)
r = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(up2)

autoencoder = Model(inputs=x, outputs=r)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# %%
autoencoder.summary()
# Out:
# Model: "model_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_17 (InputLayer)       [(None, 28, 28, 1)]       0
#
#  conv2d_28 (Conv2D)          (None, 28, 28, 32)        320
#
#  max_pooling2d_12 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_29 (Conv2D)          (None, 14, 14, 32)        9248
#
#  max_pooling2d_13 (MaxPoolin  (None, 7, 7, 32)         0
#  g2D)
#
#  conv2d_30 (Conv2D)          (None, 7, 7, 32)          9248
#
#  up_sampling2d_12 (UpSamplin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_31 (Conv2D)          (None, 14, 14, 32)        9248
#
#  up_sampling2d_13 (UpSamplin  (None, 28, 28, 32)       0
#  g2D)
#
#  conv2d_32 (Conv2D)          (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 28,353
# Trainable params: 28,353
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ###Training

# %%
epochs = 3
batch_size = 128

history = autoencoder.fit(X_train_noisy, X_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(X_test_noisy, X_test))
# Out:
# Epoch 1/3
# 469/469 [==============================] - 140s 297ms/step - loss: -121330136.0000 - val_loss: -241564794880.0000
# Epoch 2/3
# 469/469 [==============================] - 136s 291ms/step - loss: -3267290852110297934459830272.0000 - val_loss: -7030953777305696788270809088.0000
# Epoch 3/3
# 469/469 [==============================] - 137s 291ms/step - loss: -10695259292293139024196927488.0000 - val_loss: -14825023088777196764494036992.0000

# %% [markdown]
# ###Predict on the test set

# %%
decoded_imgs = autoencoder.predict(X_test_noisy)

# %% [markdown]
# ###Plot

# %%
n = 10
plt.figure(figsize=(20, 6))
for i in range(n):
    # display original
    ax = plt.subplot(3, n, i+1)
    plt.imshow(X_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    
    # display reconstruction
    ax = plt.subplot(3, n, i+n+1)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
plt.show()

# %% [markdown]
# ###Plot the losses

# %%
print(history.history.keys())

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'val_loss'])
